# %% [markdown]
# <a href="https://colab.research.google.com/github/VanshikaShyamChoudhary/Davis_Training/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
#to find hcf of 2 numbers
num1 = int (input("enter first number:"))
num2 = int (input("enter second number:"))
if (num2 == 0):
  print("HCF :" ,num1)
else:
   while(num2 !=0):
    rem = num1 % num2
    num1 = num2
    num2 = rem
    print("HCF :" ,num1)
# Out:
# enter first number:54
# enter second number:76
# HCF : 76
# HCF : 54
# HCF : 22
# HCF : 10
# HCF : 2

# %%
#wap to display even factors of a number
num = int (input("enter number:"))

print ("even factors are:")
for i in range (2, num + 1, 2):
  if num % i ==0:
    print(i)
# Out:
# enter number:76
# even factors are:
# 2
# 4
# 38
# 76

# %%
#factorial of a number
num = int(input("Enter a number: "))
fact = 1

if num < 0:
    print("Factorial does not exist")
elif num == 0:
    print("Factorial is 1")
else:
    for i in range(1, num + 1):
        fact = fact * i
    print("Factorial is:", fact)
# Out:
# Enter a number: 87
# Factorial is: 2107757298379527717213600518699389595229783738061356212322972511214654115727593174080683423236414793504734471782400000000000000000000

# %%
#program to check a number of odd or even
def checkNumber(n):
  if n%2 == 0:
    return True
  else:
    return False

  #main program
  num = int(input("Enter the number :"))
if checkNumber(num):
    print("Even number")
else:
    print("Odd number")
# Out:
# Odd number

# %%
######################################################## 50 QUESTIONS FOR PRACTISE ###########################################################

# %%
#A shopkeeper wants to calculate total bill after discount.
def calculateBill(price, discount):
    return price - (price * discount) / 100

# %%
# Check whether a person is eligible to vote
def voterElegibility(v):
  if v >= 18:
    return True
  else:
    return False

    #main program
    num = int(input("Enter the age :"))
    if voterElegibility (v):
      print ("Person is elegiblr to vote")
    else:
      print ("Person is not elegible to vote")
