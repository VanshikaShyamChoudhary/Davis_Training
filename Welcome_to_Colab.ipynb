# %% [markdown]
# <a href="https://colab.research.google.com/github/VanshikaShyamChoudhary/Davis_Training/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to find hcf of 2 numbers
num1 = int (input("enter first number:"))
num2 = int (input("enter second number:"))
if (num2 == 0):
  print("HCF :" ,num1)
else:
   while(num2 !=0):
    rem = num1 % num2
    num1 = num2
    num2 = rem
    print("HCF :" ,num1)
# Out:
# enter first number:45
# enter second number:65
# HCF : 65
# HCF : 45
# HCF : 20
# HCF : 5
