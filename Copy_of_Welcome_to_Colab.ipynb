# %% [markdown]
# <a href="https://colab.research.google.com/github/VanshikaShyamChoudhary/Davis_Training/blob/main/Copy_of_Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to find hcf of 2 numbers
num1 = int (input("enter first number:"))
num2 = int (input("enter second number:"))
if (num2 == 0):
  print("HCF :" ,num1)
else:
   while(num2 !=0):
    rem = num1 % num2
    num1 = num2
    num2 = rem
    print("HCF :" ,num1)
# Out:
# enter first number:56
# enter second number:76
# HCF : 76
# HCF : 56
# HCF : 20
# HCF : 16
# HCF : 4

# %%
#wap to display even factors of a number
num = int (input("enter number:"))

print ("even factors are:")
for i in range (2, num + 1, 2):
  if num % i ==0:
    print(i)
# Out:
# enter number:56
# even factors are:
# 2
# 4
# 8
# 14
# 28
# 56

# %%
#factorial of a number
num = int(input("Enter a number: "))
fact = 1

if num < 0:
    print("Factorial does not exist")
elif num == 0:
    print("Factorial is 1")
else:
    for i in range(1, num + 1):
        fact = fact * i
    print("Factorial is:", fact)
# Out:
# Enter a number: 56
# Factorial is: 710998587804863451854045647463724949736497978881168458687447040000000000000

# %%
#program to check a number of odd or even
def checkNumber(n):
  if n%2 == 0:
    return True
  else:
    return False

  #main program
  num = int(input("Enter the number :"))

  if checkNumber(num):
    print ("The number is : Even")
  else:
    print ("The number is : Odd")
